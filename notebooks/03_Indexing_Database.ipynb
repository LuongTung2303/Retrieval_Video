# %%
import sys
import os

# Thư mục gốc để import src
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Import class vừa viết
from src.database.milvus_client import HybridMilvusDatabase

# Thay bằng thông tin thực tế của bạn lấy ở Bước 1
ZILLIZ_URI = "ĐIỀN_URI_CỦA_BẠN_VÀO_ĐÂY"
ZILLIZ_TOKEN = "ĐIỀN_TOKEN_CỦA_BẠN_VÀO_ĐÂY"

# Khởi tạo và tạo bảng
db = HybridMilvusDatabase(uri=ZILLIZ_URI, token=ZILLIZ_TOKEN)
db.create_hybrid_collection()
