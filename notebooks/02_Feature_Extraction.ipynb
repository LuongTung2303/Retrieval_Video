# %%
import os
import sys
from google.colab import drive

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Định nghĩa đường dẫn tới thư mục gốc (RETRIEVAL_VIDEO)
# Bạn hãy thay đổi 'Project_Path' cho đúng với thực tế trên Drive của bạn
PROJECT_ROOT = "/content/drive/MyDrive/University/HK8/Big Data/Retrieval_Video"
os.chdir(PROJECT_ROOT)

# 3. Thêm PROJECT_ROOT vào sys.path để Python nhận diện được folder 'src'
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# 4. Cài đặt thư viện từ file requirements.txt có sẵn của bạn
# !pip install -r requirements.txt
